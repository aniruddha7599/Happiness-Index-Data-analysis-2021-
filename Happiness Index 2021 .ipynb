# %% [markdown]
# # Happiness Index

# %% [markdown]
# ## Importing Libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd 
# %matplotlib inline

# %% [markdown]
# ## Reading CSV file

# %%
df=pd.read_csv('2021.csv')
df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %% [markdown]
# ## Sorting rows for India

# %%
India=df[df['Country name']=='India']
India
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 732        India  2006        5.348               8.145           0.707
# 733        India  2007        5.027               8.204           0.569
# 734        India  2008        5.146               8.220           0.684
# 735        India  2009        4.522               8.281           0.653
# 736        India  2010        4.989               8.349           0.605
# 737        India  2011        4.635               8.387           0.553
# 738        India  2012        4.720               8.428           0.511
# 739        India  2013        4.428               8.478           0.553
# 740        India  2014        4.424               8.538           0.621
# 741        India  2015        4.342               8.604           0.610
# 742        India  2016        4.179               8.673           0.614
# 743        India  2017        4.046               8.730           0.607
# ...

# %% [markdown]
# ## Statistical data for India

# %%
India.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count    15.000000    15.000000           15.000000       15.000000
# mean   2013.000000     4.473200            8.489133        0.606867
# std       4.472136     0.545137            0.222764        0.052079
# min    2006.000000     3.249000            8.145000        0.511000
# 25%    2009.500000     4.202000            8.315000        0.565000
# 50%    2013.000000     4.428000            8.478000        0.610000
# 75%    2016.500000     4.854500            8.688000        0.629500
# max    2020.000000     5.348000            8.818000        0.707000
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                         15.000000                     15.000000
# mean                          58.320000                      0.791467
# std                            1.594544                      0.083038
# min                           55.720000                      0.609000
# ...

# %% [markdown]
# ## Plot for "Life ladder" vs "year"

# %%
plt.figure(figsize=(20,7))
plt.plot(India['year'],India['Life Ladder'],linestyle='-',marker='*',color='darkorange')
plt.title("Life Ladder")
plt.xlim(2005,2021)
plt.ylim(3,5.5)
plt.grid()
plt.show()

# %% [markdown]
# ## Plot for "GDP per capita" vs"year"

# %%
plt.figure(figsize=(20,7))
plt.plot(India['year'],India['Log GDP per capita'],linestyle='-',marker='o',color='red')
plt.title("Log GDP per capita")
plt.xlim(2005,2021)
plt.ylim(8,9,0.1)
plt.grid()
plt.show()

# %% [markdown]
# ## Plot for "Social Support" vs"year"

# %%
plt.figure(figsize=(20,7))
plt.plot(India['year'],India['Social support'],linestyle='-.',marker='*',color='green')
plt.title("Social support")
plt.xlim(2005,2021)
plt.ylim(0.500,0.750)
plt.grid()
plt.show()

# %% [markdown]
# ## Plot for "Healthy life expectancy at birth" vs"year"

# %%
plt.figure(figsize=(20,7))
plt.plot(India['year'],India['Healthy life expectancy at birth'],linestyle=':',marker='*',color='magenta')
plt.xlim(2005,2021)
plt.ylim(55,62)
plt.title("Healthy life expectancy at birth")
plt.grid()
plt.show()

# %% [markdown]
# ## Plot for "Freedom to make life choices" vs "year"

# %%
plt.figure(figsize=(20,7))
plt.plot(India['year'],India['Freedom to make life choices'],linestyle='--',marker='o',color='black')
plt.title("Freedom to make life choices")
plt.xlim(2005,2021)
plt.ylim(0.55,0.95)
plt.grid()
plt.show()

# %% [markdown]
# ## Plot for "Generosity" vs "year"

# %%
plt.figure(figsize=(20,7))
plt.plot(India['year'],India['Generosity'],linestyle='solid',marker='o',color='brown')
plt.title("Generosity")
plt.xlim(2005,2021)
plt.ylim(-0.0850,0.120)
plt.grid()
plt.show()

# %% [markdown]
# ## Plot for "Perceptions of corruption" vs "year"

# %%
plt.figure(figsize=(20,7))
plt.plot(India['year'],India['Perceptions of corruption'],linestyle=':',marker='o',color='steelblue')
plt.title("Perceptions of corruption")
plt.xlim(2005,2021)
plt.ylim(0.72,0.92)
plt.grid()
plt.show()

# %% [markdown]
# ## Plot for "Positive Effect" vs "year"

# %%
plt.figure(figsize=(20,7))
plt.plot(India['year'],India['Positive affect'],linestyle='-.',marker='o',color='olive')
plt.title("Positive affect")
plt.xlim(2005,2021)
plt.ylim(0.62,0.78)
plt.grid()
plt.show()

# %% [markdown]
# ## Plot for "Negative Effect" vs "year"

# %%
plt.figure(figsize=(20,7))
plt.plot(India['year'],India['Negative affect'],linestyle='-',marker='o',color='gray')
plt.title("Negative affect")
plt.xlim(2005,2021)
plt.ylim(0.18,0.48)
plt.grid()
plt.show()

# %% [markdown]
# ## Plot for "Happines Index" vs "year"

# %%
plt.figure(figsize=(20,7))
plt.plot(India['year'],India['Happines Index '],marker='o',color='orange')
plt.title("Happines Index ")
plt.xlim(2005,2021)
plt.ylim(8,8.7)
plt.grid()
plt.show()

# %% [markdown]
# ## Reseting Index

# %%
IN = India.reset_index(drop=True)
IN
# Out:
#    Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0         India  2006        5.348               8.145           0.707
# 1         India  2007        5.027               8.204           0.569
# 2         India  2008        5.146               8.220           0.684
# 3         India  2009        4.522               8.281           0.653
# 4         India  2010        4.989               8.349           0.605
# 5         India  2011        4.635               8.387           0.553
# 6         India  2012        4.720               8.428           0.511
# 7         India  2013        4.428               8.478           0.553
# 8         India  2014        4.424               8.538           0.621
# 9         India  2015        4.342               8.604           0.610
# 10        India  2016        4.179               8.673           0.614
# 11        India  2017        4.046               8.730           0.607
# ...

# %%
IN.drop(["Country name", "year","Happines Index "], axis=1, inplace =True)
y2006=IN[:1][:]
y2006
# Out:
#    Life Ladder  Log GDP per capita  Social support  \
# 0        5.348               8.145           0.707
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             55.72                         0.774       0.052
#
#    Perceptions of corruption  Positive affect  Negative affect
# 0                      0.855            0.687            0.199

# %%
y2006.columns
# Out:
# Index(['Life Ladder', 'Log GDP per capita', 'Social support',
#        'Healthy life expectancy at birth', 'Freedom to make life choices',
#        'Generosity', 'Perceptions of corruption', 'Positive affect',
#        'Negative affect'],
#       dtype='object')

# %%
plt.figure(figsize=(20,7))
plt.pie(y2006.values[0], labels=y2006.columns,shadow=True,radius=1.5,explode=[0,0,0,0,0,0,0,0,0])
plt.legend(bbox_to_anchor=[1.5,1])
plt.show()
